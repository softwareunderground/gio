# %%
import parsimonious
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-81c8b6311557> in <module>()
# ----> 1 import parsimonious
#
# ModuleNotFoundError: No module named 'parsimonious'

# %% [markdown]
# # Reading SPWLA file
#
# The 3 methods for extracting data are:
#
# - Looping over the file and applying string methods, etc.
# - Using regex to extract everything at once.
# - Using a parser.
#
#
# ## Looping SPWLA file
#
# Let's start by just trying to read the file.

# %%
# !head -24 ../data/core_analysis_example.spwla
# Out:
# 10     2
#     9999/9-9                                Norway                                            9Sep99
#     Weatherford-Labs
# 15    10   10
#           1507      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Hor.
#           1512      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Hor.
#           1510      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Vert.
#           1515      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Vert.
#           1402      1211  3084   0Weatherford-Labs    Porosity, Horizontal PLUG
#           1403      1211  3084   0Weatherford-Labs    Porosity, Vertical PLUG
#           1401      1212  3084   0Weatherford-Labs    Porosity, Summation
#           1302      1103  3085   0Weatherford-Labs    CORE Oil Saturation
#           1301      1103  3085   0Weatherford-Labs    CORE Water Saturation
#           2451      1201  1086   0Weatherford-Labs    Grain Density, Hor.
# 20     1
#         0.00     0.00  1918.00  1983.72  0.0  1
# 30     1
#      1918.95     0.00   1.11
# 40     1   10
#      -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    18.44722 -1002.00000    14.78718 -1002.00000 -1002.00000
# 30     1
#      1919.95     0.00   2.11
# 40     1   10
#      -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    17.06246 -1002.00000    18.06427 -1002.00000 -1002.00000

# %% [markdown]
# ### Observations
#
# - Some lines are 128 characters wide
# - Some of the data is unidentifiable
# - This is probably a job for striplog
# - The info after the record type (10, 15, 20, 30, etc) seems to be the number of lines (and fields per line, perhaps) in that record, which is redundant information (can just read until the next record type flag)

# %%
record_fields = {
    'header': [['well', 'country', 'date'], ['company']],  # Occurs on 2 lines
    'features': ['a', 'b', 'c', 'd', 'company', 'feature'],
    'range': ['w', 'x', 'start', 'stop', 'y', 'z'],
    'depth': ['depth', 'alpha', 'beta'],
    'descr': ['description'],
    'data': ['data'],  # Capture as array
}

# %%
record_type = {
    10: 'header',
    15: 'features',
    20: 'range',
    30: 'depth',
    36: 'descr',
    40: 'data',
}

# %%
fname = "../data/core_analysis_example.spwla"

with open(fname, 'r') as f:
    data = f.read()

def get_blocks(data):
    for line in data:
        if line[:2].isnumeric():
            code = line[:2]
            continue
        yield code, line

for code, line in get_blocks(data.split('\n')):
    rec_type = record_type[int(code)]
    fields = record_fields[rec_type]
    
    features = []
    if rec_type == 'features':
        features.append(None)

# %% [markdown]
# ## Regex SPWLA file
#
# From [this StackOverflow question](https://stackoverflow.com/questions/47982949/how-to-parse-complex-text-files-using-python).

# %%
s = """10     2                                                                                                                       
    9999/9-9                                Norway                                            9Sep99
    Weatherford-Labs
15    10   10
          1507      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Hor.
          1512      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Hor.
          1510      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Vert.
          1515      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Vert.
          1402      1211  3084   0Weatherford-Labs    Porosity, Horizontal PLUG
          1403      1211  3084   0Weatherford-Labs    Porosity, Vertical PLUG
          1401      1212  3084   0Weatherford-Labs    Porosity, Summation
          1302      1103  3085   0Weatherford-Labs    CORE Oil Saturation
          1301      1103  3085   0Weatherford-Labs    CORE Water Saturation
          2451      1201  1086   0Weatherford-Labs    Grain Density, Hor.
20     1
        0.00     0.00  1918.00  1983.72  0.0  1
30     1
     1918.95     0.00   1.11
40     1   10
     -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    18.44722 -1002.00000    14.78718 -1002.00000 -1002.00000
30     1
     1919.95     0.00   2.11
40     1   10
     -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    17.06246 -1002.00000    18.06427 -1002.00000 -1002.00000
     """

# %%
# TESTING
s = "     1401      1212  3084   0Weatherford-Labs    Porosity, Summation\n"

rx_field = re.compile(r'''
    ^
    \s+?\d+?\s+?\d+?\s+?\d+?\s+?0\S+?\s+?(?P<field>[\w\d][- ,.\w\d]+?)\n
''', re.MULTILINE | re.VERBOSE)

[f.group('field') for f in rx_field.finditer(s)]
# Out:
# ['Porosity, Summation']

# %%
import re

# Not using this one.
# rx_fields = re.compile(r'''
#     ^
#     15\s+?\d+?\s+?\d+?\n
#     (?P<fields>[\s\S]+?)
#     (?=^[^1]|\Z)
# ''', re.MULTILINE | re.VERBOSE)

rx_fields = re.compile(r'''
    ^
    \s+?\d+?\s+?\d+?\s+?\d+?\s+?0\S+?\s+?(?P<field>[\w\d][- ,.\w\d]+?)\n
''', re.MULTILINE | re.VERBOSE)

rx_depth = re.compile(r'''
    ^
    30\s+?1\n
    \s+?(?P<depth>[.\d]+?)[ \t]+?[.\d]+?[ \t]+?(?P<seq>[.\d]+?)\n
    (?P<record>[\s\S]+?)
    (?=^30|\Z)
''', re.MULTILINE | re.VERBOSE)

rx_data = re.compile(r'''
    ^
    (?:36\s+?1\s+?1\n
    \s+?(?P<descr>.+?)\n)?
    40\s+?1\s+?\d+?\n
    \s+?(?P<data>[- .\d]+?)\n
''', re.MULTILINE | re.VERBOSE)

# %%
import pandas as pd
import numpy as np

def parse(s, null=-999.25): 
    
    records = (field.group('field') for field in rx_fields.finditer(s))

    result = (
              (
                float(record.group('depth')),
                record.group('seq'),
                data.group('descr'),
                *[float(x) for x in data.group('data').split()]
              )
               for record in rx_depth.finditer(s)
               for data in rx_data.finditer(record.group('record'))
    )

    columns = ['depth', 'seq', 'descr'] + list(records)
    
    df = pd.DataFrame(result, columns=columns)
    df = df.replace(null, np.nan)

    return df

# %%
parse(data, null=-1002)
# Out:
#        depth    seq                                              descr  \
# 0    1918.95   1.11                                               None
# 1    1919.95   2.11                                               None
# 2    1920.95   3.11                                               None
# 3    1921.95   4.11                                               None
# 4    1922.95   5.11                                               None
# 5    1923.95   6.11                                               None
# 6    1924.95   7.11                                               None
# 7    1925.95   8.11                                               None
# 8    1926.95   9.11                                               None
# 9    1927.95  10.11                                               None
# 10   1928.95  11.11                                               None
# 11   1929.95  12.11                                               None
# 12   1930.95  13.11                                               None
# 13   1931.95  14.11                                               None
# 14   1932.95  15.11                                               None
# 15   1933.95  16.11                                               None
# 16   1934.95  17.11                                               None
# 17   1935.95  18.11                                               None
# 18   1936.95  19.11                                               None
# 19   1937.95  20.11                                               None
# 20   1938.95  21.11                                               None
# 21   1940.95  22.11                                               None
# 22   1941.95  23.11                                               None
# 23   1942.95  24.11                                               None
# 24   1943.95  25.11                                               None
# 25   1944.95  26.11                                               None
# 26   1945.95  27.11                                               None
# 27   1946.95  28.11                                               None
# 28   1947.95  29.11                                               None
# 29   1948.95  30.11                                               None
# ..       ...    ...                                                ...
# 298  1976.50    235     Sst.Lt-gry.VF-gr.VW-Consol.VW-srt.Lam.w-C,C...
# 299  1976.75    236     Sst.Lt-gry.VF-gr.VW-Consol.VW-srt.Lam.w-C,C...
# 300  1977.02    237     Sst.Lt-gry.VF-gr.VW-Consol.VW srt.w-C,Cl,Mi...
# 301  1977.25    238     Sst.Lt-gry.VF-gr.VW-Consol.VW srt.Lam.w-C,C...
# 302  1977.51    239     Sst.Lt-gry.VF/F-gr.VW-Consol.W srt.Fis.w-Cl...
# 303  1977.77    240     Sst.Lt-gry.VF-gr.VW-Consol.VW srt.Fis.w-C,C...
# 304  1978.32    241     Sst.Lt-gry.VF/M-gr.VW Consol.M srt.Lam.Frac...
# 305  1978.50    242     Sst.Lt-gry.VF/F-gr.VW Consol.W srt.w-tr Cal...
# 306  1978.70    243     Sst.Lt-gry.VF/F-gr.VW Consol.VW-srt.Lam.w-C...
# 307  1978.88    244     Slsty Sst.MLt-gry.VF-gr.VW Consol.VW-srt.La...
# 308  1979.02    245     Sst.Yelsh-gry.VF/M-gr.VW Consol.M-srt.Lam.F...
# 309  1979.25    246      Sst.VLt-gry.F/M-gr.Sbang.W-cmt.M-srt.w-tr Cl.
# 310  1979.46    247     Sst.Lt-gry.VF-gr.VW Consol.VW-srt.Fis.w-C,C...
# 311  1979.75    248     Sst.Lt-gry.VF/F-gr.VW Consol.W-srt.Thin Lam...
# 312  1980.02    249     Sst.Lt-gry.VF/F-gr.Sbang.W-cmt.W-srt.w-ltl ...
# 313  1980.23    250     Sst.Lt-gry.VF/F-gr.Sbang.W-cmt.W-srt.w-ltl ...
# 314  1980.50    251     Sst.Lt-gry.VF/F-gr.Sbang.W-cmt.W-srt.w-ltl ...
# 315  1980.75    252     Sst.Lt-gry.VF/C-gr.Sbang.W-cmt.P-srt.w-ltl ...
# 316  1981.02    253     Sst.Lt-gry.VF/M-gr.Sbang.W-cmt.M-srt.Irr La...
# 317  1981.25    254     Sst.Lt-gry.VF/F-gr.Sbang.W-cmt.W-srt.w-tr C...
# 318  1981.51    255     Sst.Lt-gry.VF/M-gr.Sbang.W-cmt.M-srt.w-Cl,Mic.
# 319  1981.75    256     Sst.Lt-gry.VF/C-gr.Sbang.W-cmt.P-srt.w-Cl,Mic.
# 320  1982.12    257     Sst.Lt-gry.F/M-gr.Sbang.W-cmt.M-srt.tr Mtrx...
# 321  1982.35    258     Sst.Lt-gry.VF/M-gr.Sbang.W-cmt.M-srt.w-llt ...
# 322  1982.57    259     Sst.Lt-gry.VF/VC-gr.Sbang.W-cmt.VP-srt.Mtrx...
# 323  1982.79    260     Sst.Lt-gry.VF/VC-gr.Gran.Sbang.W-cmt.VP-srt...
# 324  1983.02    261     Sst.Lt-gry.VF/VC-gr.Gran.Sbang.W-cmt.VP-srt...
# 325  1983.24    262     Sst.Lt-gry.VF/VC-gr.Sbang.W-cmt.VP-srt.w-lt...
# 326  1983.44    263     Sst.Lt Olv-gry.VF/F-gr.Sbang.W-cmt.W-srt.La...
# 327  1983.70    264     Sst.Yelsh-gry.VF/F-gr.Sbang.W-cmt.W-srt.Lam...
#
#      Nitrogen Permeability, Hor.  Klinkenberg corrected gas perm, Hor.  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
# 5                            NaN                                   NaN
# 6                            NaN                                   NaN
# 7                            NaN                                   NaN
# 8                            NaN                                   NaN
# 9                            NaN                                   NaN
# 10                           NaN                                   NaN
# 11                           NaN                                   NaN
# 12                           NaN                                   NaN
# 13                           NaN                                   NaN
# 14                           NaN                                   NaN
# 15                           NaN                                   NaN
# 16                           NaN                                   NaN
# 17                           NaN                                   NaN
# 18                           NaN                                   NaN
# 19                           NaN                                   NaN
# 20                           NaN                                   NaN
# 21                           NaN                                   NaN
# 22                           NaN                                   NaN
# 23                           NaN                                   NaN
# 24                           NaN                                   NaN
# 25                           NaN                                   NaN
# 26                           NaN                                   NaN
# 27                           NaN                                   NaN
# 28                           NaN                                   NaN
# 29                           NaN                                   NaN
# ..                           ...                                   ...
# 298                        0.093                                 0.055
# 299                        0.166                                 0.102
# 300                        0.239                                 0.149
# 301                        0.194                                 0.120
# 302                        6.642                                 5.095
# 303                        0.959                                 0.651
# 304                        0.000                                 0.000
# 305                       40.739                                35.064
# 306                        0.098                                 0.058
# 307                        0.107                                 0.064
# 308                        6.085                                 4.677
# 309                     1722.764                              1651.775
# 310                        0.995                                 0.676
# 311                        9.106                                 7.117
# 312                      558.779                               523.998
# 313                      559.596                               524.704
# 314                      420.865                               391.804
# 315                      909.761                               862.228
# 316                       61.320                                53.515
# 317                      151.734                               137.053
# 318                        1.178                                 0.809
# 319                        3.772                                 2.815
# 320                       38.395                                32.908
# 321                      217.808                               198.934
# 322                       91.605                                81.311
# 323                     1823.535                              1750.044
# 324                      517.099                               484.015
# 325                      650.344                               612.018
# 326                        0.000                                 0.000
# 327                        0.000                                 0.000
#
#      Nitrogen Permeability, Vert.  Klinkenberg corrected gas perm, Vert.  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
# 5                             NaN                                    NaN
# 6                             NaN                                    NaN
# 7                             NaN                                    NaN
# 8                             NaN                                    NaN
# 9                             NaN                                    NaN
# 10                            NaN                                    NaN
# 11                            NaN                                    NaN
# 12                            NaN                                    NaN
# 13                            NaN                                    NaN
# 14                            NaN                                    NaN
# 15                            NaN                                    NaN
# 16                            NaN                                    NaN
# 17                            NaN                                    NaN
# 18                            NaN                                    NaN
# 19                            NaN                                    NaN
# 20                            NaN                                    NaN
# 21                            NaN                                    NaN
# 22                            NaN                                    NaN
# 23                            NaN                                    NaN
# 24                            NaN                                    NaN
# 25                            NaN                                    NaN
# 26                            NaN                                    NaN
# 27                            NaN                                    NaN
# 28                            NaN                                    NaN
# 29                            NaN                                    NaN
# ..                            ...                                    ...
# 298                         0.017                                  0.009
# 299                         0.025                                  0.013
# 300                         0.112                                  0.067
# 301                         0.024                                  0.013
# 302                         4.422                                  3.352
# 303                         0.227                                  0.141
# 304                         0.132                                  0.080
# 305                        20.687                                 17.017
# 306                         0.109                                  0.065
# 307                         0.074                                  0.043
# 308                         7.569                                  6.100
# 309                       486.432                                454.547
# 310                         0.084                                  0.049
# 311                        11.609                                  9.429
# 312                       596.169                                559.849
# 313                       439.650                                409.777
# 314                       147.913                                133.392
# 315                       219.213                                200.279
# 316                        14.042                                 11.348
# 317                       183.173                                166.378
# 318                         0.237                                  0.148
# 319                         2.247                                  1.757
# 320                         0.219                                  0.136
# 321                       260.715                                239.469
# 322                       628.956                                591.362
# 323                       628.296                                590.727
# 324                       142.276                                128.133
# 325                       132.574                                119.098
# 326                         1.820                                  1.283
# 327                         0.040                                  0.022
#
#      Porosity, Horizontal PLUG  Porosity, Vertical PLUG  Porosity, Summation  \
# 0                          NaN                 18.44722                  NaN
# 1                          NaN                 17.06246                  NaN
# 2                          NaN                 19.58139                  NaN
# 3                          NaN                 18.32791                  NaN
# 4                          NaN                 16.67100                  NaN
# 5                          NaN                 15.49629                  NaN
# 6                          NaN                 18.28268                  NaN
# 7                          NaN                 18.43782                  NaN
# 8                          NaN                 17.31157                  NaN
# 9                          NaN                 19.34322                  NaN
# 10                         NaN                 18.61451                  NaN
# 11                         NaN                 16.17023                  NaN
# 12                         NaN                 18.13845                  NaN
# 13                         NaN                 13.27176                  NaN
# 14                         NaN                 10.50659                  NaN
# 15                         NaN                 16.97168                  NaN
# 16                         NaN                 16.40207                  NaN
# 17                         NaN                 22.72481                  NaN
# 18                         NaN                 18.41375                  NaN
# 19                         NaN                 18.85675                  NaN
# 20                         NaN                 17.93774                  NaN
# 21                         NaN                 18.46985                  NaN
# 22                         NaN                 14.96825                  NaN
# 23                         NaN                 19.11698                  NaN
# 24                         NaN                 17.74624                  NaN
# 25                         NaN                 11.29837                  NaN
# 26                         NaN                 19.35403                  NaN
# 27                         NaN                 15.65132                  NaN
# 28                         NaN                 13.45465                  NaN
# 29                         NaN                 16.54562                  NaN
# ..                         ...                      ...                  ...
# 298                   11.42335                      NaN                  NaN
# 299                    8.34043                      NaN                  NaN
# 300                   13.71619                      NaN                  NaN
# 301                   12.92918                      NaN                  NaN
# 302                   15.37053                      NaN                  NaN
# 303                   12.76678                      NaN                  NaN
# 304                   11.33350                      NaN                  NaN
# 305                   17.51168                      NaN                  NaN
# 306                   10.33719                      NaN                  NaN
# 307                   11.68598                      NaN                  NaN
# 308                   11.51438                      NaN                  NaN
# 309                   20.38721                      NaN                  NaN
# 310                   11.05768                      NaN                  NaN
# 311                   13.00959                      NaN                  NaN
# 312                   22.93377                      NaN                  NaN
# 313                   22.26690                      NaN                  NaN
# 314                   21.65629                      NaN                  NaN
# 315                   23.23437                      NaN                  NaN
# 316                   16.89518                      NaN                  NaN
# 317                   17.80920                      NaN                  NaN
# 318                   11.41745                      NaN                  NaN
# 319                   16.10870                      NaN                  NaN
# 320                   14.17604                      NaN                  NaN
# 321                   20.34436                      NaN                  NaN
# 322                   17.65817                      NaN                  NaN
# 323                   21.23241                      NaN                  NaN
# 324                   19.07649                      NaN                  NaN
# 325                   15.08463                      NaN                  NaN
# 326                    9.44161                      NaN                  NaN
# 327                    7.41085                      NaN                  NaN
#
#      CORE Oil Saturation  CORE Water Saturation  Grain Density, Hor.
# 0               14.78718                    NaN                  NaN
# 1               18.06427                    NaN                  NaN
# 2               19.01052                    NaN                  NaN
# 3               17.92610                    NaN                  NaN
# 4               20.77644                    NaN                  NaN
# 5               24.60543                    NaN                  NaN
# 6               12.88050                    NaN                  NaN
# 7               13.75609                    NaN                  NaN
# 8               14.66162                    NaN                  NaN
# 9               13.08335                    NaN                  NaN
# 10              18.12203                    NaN                  NaN
# 11              14.21380                    NaN                  NaN
# 12              11.11148                    NaN                  NaN
# 13              12.31301                    NaN                  NaN
# 14              19.31734                    NaN                  NaN
# 15              21.41411                    NaN                  NaN
# 16              43.12578                    NaN                  NaN
# 17              55.43833                    NaN                  NaN
# 18              59.59112                    NaN                  NaN
# 19              50.40101                    NaN                  NaN
# 20              44.58358                    NaN                  NaN
# 21              49.18243                    NaN                  NaN
# 22              47.84605                    NaN                  NaN
# 23              47.18030                    NaN                  NaN
# 24              47.80520                    NaN                  NaN
# 25              46.18566                    NaN                  NaN
# 26              45.72604                    NaN                  NaN
# 27              47.17111                    NaN                  NaN
# 28              40.23944                    NaN                  NaN
# 29              34.87458                    NaN                  NaN
# ..                   ...                    ...                  ...
# 298                  NaN                    NaN              2.65691
# 299                  NaN                    NaN              2.63852
# 300                  NaN                    NaN              2.66542
# 301                  NaN                    NaN              2.65561
# 302                  NaN                    NaN              2.66011
# 303                  NaN                    NaN              2.65316
# 304                  NaN                    NaN              2.64860
# 305                  NaN                    NaN              2.68379
# 306                  NaN                    NaN              2.66098
# 307                  NaN                    NaN              2.66552
# 308                  NaN                    NaN              2.65606
# 309                  NaN                    NaN              2.64458
# 310                  NaN                    NaN              2.64788
# 311                  NaN                    NaN              2.69492
# 312                  NaN                    NaN              2.66242
# 313                  NaN                    NaN              2.65279
# 314                  NaN                    NaN              2.65754
# 315                  NaN                    NaN              2.65884
# 316                  NaN                    NaN              2.68712
# 317                  NaN                    NaN              2.66355
# 318                  NaN                    NaN              2.65450
# 319                  NaN                    NaN              2.65847
# 320                  NaN                    NaN              2.64581
# 321                  NaN                    NaN              2.67607
# 322                  NaN                    NaN              2.66311
# 323                  NaN                    NaN              2.64861
# 324                  NaN                    NaN              2.65108
# 325                  NaN                    NaN              2.65493
# 326                  NaN                    NaN              2.76367
# 327                  NaN                    NaN                  NaN
#
# [328 rows x 13 columns]

# %% [markdown]
# ## Parsing SPWLA file
#
# Let's try using `parsimonious`. Example from [the docs](https://github.com/erikrose/parsimonious):

# %%
from parsimonious.grammar import Grammar
from parsimonious.nodes import NodeVisitor

class EntryParser(NodeVisitor):
    def __init__(self, grammar, text):
        self.entry = {}
        ast = Grammar(grammar).parse(text)
        self.visit(ast)
    def visit_name(self, n, vc):
        self.entry['name'] = n.text
    def visit_gender(self, n, vc):
        self.entry['gender'] = n.text
    def visit_age(self, n, vc):
        self.entry['age'] = n.text
    def generic_visit(self, n, vc):
        pass

grammar = """\
entry = name sep gender? (sep age)?
sep = ws "," ws
ws = " "*
name = ~"[A-z]*"
gender = "male" / "female"
age = ~"[0-9]*"
"""

text = """\
Bob, male, 26
Kim,female,30
Joe,male
"""

for line in text.splitlines():
    print(EntryParser(grammar, line).entry)
# Out:
# -----------------------------------------------------------------
# ModuleNotFoundError             Traceback (most recent call last)
# <ipython-input-8-67628c2c6d10> in <module>
# ----> 1 from parsimonious.grammar import Grammar
#       2 from parsimonious.nodes import NodeVisitor
#       3
#       4 class EntryParser(NodeVisitor):
#       5     def __init__(self, grammar, text):
#
# ModuleNotFoundError: No module named 'parsimonious'

# %%
# !head -24 ../data/core_analysis_example.spwla
# Out:
# 10     2
#     9999/9-9                                Norway                                            9Sep99
#     Weatherford-Labs
# 15    10   10
#           1507      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Hor.
#           1512      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Hor.
#           1510      1602  2031   0Weatherford-Labs    Nitrogen Permeability, Vert.
#           1515      1602  2031   0Weatherford-Labs    Klinkenberg corrected gas perm, Vert.
#           1402      1211  3084   0Weatherford-Labs    Porosity, Horizontal PLUG
#           1403      1211  3084   0Weatherford-Labs    Porosity, Vertical PLUG
#           1401      1212  3084   0Weatherford-Labs    Porosity, Summation
#           1302      1103  3085   0Weatherford-Labs    CORE Oil Saturation
#           1301      1103  3085   0Weatherford-Labs    CORE Water Saturation
#           2451      1201  1086   0Weatherford-Labs    Grain Density, Hor.
# 20     1
#         0.00     0.00  1918.00  1983.72  0.0  1
# 30     1
#      1918.95     0.00   1.11
# 40     1   10
#      -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    18.44722 -1002.00000    14.78718 -1002.00000 -1002.00000
# 30     1
#      1919.95     0.00   2.11
# 40     1   10
#      -1002.00000 -1002.00000 -1002.00000 -1002.00000 -1002.00000    17.06246 -1002.00000    18.06427 -1002.00000 -1002.00000

# %%
# Define a context-free grammar.
grammar = Grammar(
    r"""
    schools         = (school_block / ws)+

    data_block    = depth_header ws data_line 
    descr_block   = grade_header ws name_header ws (number_name)+ ws score_header ws (number_score)+ ws? 

    school_header   = ~"^School = (.*)"m
    grade_header    = ~"^Grade = (\d+)"m
    depth_header    = "30 lines"
    data_header     = "40" ws "1" ws lines

    number_name     = index comma name ws
    number_score    = index comma score ws

    type            = number+
    lines           = number+

    number          = ~"\d+"
    name            = ~"[A-Z]\w+"
    depth           = ~"[.0-9]\w+"
    description     = ~"[.,- A-Za-z]+"
    ws              = ~"\s*"
    """
)

# %%
from parsimonious.nodes import NodeVisitor

class DataVisitor(NodeVisitor):
    def visit_expr(self, node, visited_children):
        """ Returns the overall output. """
        output = {}
        for child in visited_children:
            output.update(child[0])
        return output

    def visit_entry(self, node, visited_children):
        """ Makes a dict of the section (as key) and the key/value pairs. """
        key, values = visited_children
        return {key: dict(values)}

    def visit_section(self, node, visited_children):
        """ Gets the section name. """
        _, section, *_ = visited_children
        return section.text

    def visit_pair(self, node, visited_children):
        """ Gets each key/value pair, returns a tuple. """
        key, _, value, *_ = node.children
        return key.text, value.text

    def generic_visit(self, node, visited_children):
        """ The generic visit method. """
        return visited_children or node

dv = DataVisitor()
out = dv.visit(tree)

print(out)
